# %% [markdown]
# # Insper
# ## Data Science
# ### Deploy
#
# Gráficos - Jupyter notebook publicado no GitHub
#
# Arnaldo Chebl

# %%
# Source: https://python-graph-gallery.com/40-basic-scatterplot-seaborn/

# library & dataset
import seaborn as sns
import matplotlib.pyplot as plt
df = sns.load_dataset('iris')
 
# use the function regplot to make a scatterplot
sns.regplot(x=df["sepal_length"], y=df["sepal_width"])
 
# make a scatterplot without regression fit
#ax = sns.regplot(x=df["sepal_length"], y=df["sepal_width"], fit_reg=False)

plt.show()
